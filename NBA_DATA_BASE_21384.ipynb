# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Read In CSVs

# %%
raw_combine_data=pd.read_csv('Resources/raw_combine_data.csv')
raw_nba_data=pd.read_csv('Resources/raw_nba_data.csv')

# %% [markdown]
# ### Finding Duplicates

# %%
nba_duplicates=raw_nba_data[raw_nba_data.duplicated(['PLAYER'])]
combine_duplicates=raw_combine_data[raw_combine_data.duplicated(['PLAYER'])]

# %% [markdown]
# ### Drop Duplicates from Dataframes

# %%
dropped_combine_data=raw_combine_data.drop_duplicates(subset='PLAYER',keep='first')
dropped_nba_data=raw_nba_data.drop_duplicates(subset='PLAYER',keep='first')

# %% [markdown]
# ### Merge DataFrames

# %%
merged_data_df=dropped_combine_data.merge(dropped_nba_data, on='PLAYER')

# %% [markdown]
# ### Drop Rows w/ Missing Wingspan Data

# %%
merged_data_df=merged_data_df.dropna(subset=['WINGSPAN'])

# %%
merged_data_df.reset_index(inplace=True)
# Out:
#      index               PLAYER    POS BODY FAT % HAND LENGTH (INCHES)  \
# 0        0         Aaron Gordon     PF      5.05%                 8.75
# 1        1        Aaron Holiday     PG      6.40%                 8.75
# 2        2    Admiral Schofield     SF      6.80%                 8.75
# 3        3           Al Horford     PF      9.10%                    -
# 4        4           Alec Burks     SG      5.10%                    9
# ..     ...                  ...    ...        ...                  ...
# 295    300          Will Barton  SG-SF      4.10%                    9
# 296    301  Willie Cauley-Stein      C      6.30%                  9.5
# 297    302         Zach Collins   PF-C      8.90%                 8.75
# 298    303          Zach LaVine     PG      4.70%                 8.25
# 299    304         Zhaire Smith  SF-SG      6.05%                 8.75
#
#     HAND WIDTH (INCHES) HEIGHT W/O SHOES HEIGHT W/ SHOES STANDING REACH  \
# 0                  10.5         6' 7.5''       6' 8.75''         8' 9''
# 1                   8.5       5' 11.75''       6' 0.75''         8' 1''
# 2                     9           6' 4''       6' 5.25''       8' 6.5''
# 3                     -           6' 8''       6' 9.75''        8' 11''
# 4                  8.25           6' 5''          6' 6''       8' 7.5''
# ..                  ...              ...             ...            ...
# 295                 9.5           6' 5''          6' 6''       8' 6.5''
# 296                   9       6' 11.25''        7' 0.5''         9' 3''
# 297                9.25       6' 10.25''          7' 0''         9' 3''
# 298                8.75         6' 4.5''       6' 5.75''         8' 4''
# 299                8.25        6' 2.75''          6' 4''         8' 4''
#
#     WEIGHT (LBS)  ...    FT%  ORB  DRB  TRB  AST STL  BLK  TOV   PF   PTS
# 0          220.1  ...  0.675  103  338  441  215  50   36   94  116   833
# 1            187  ...  0.861   21  111  132  193  45   13   75  102   546
# 2          240.6  ...  0.692    6   28   34   14   8    3    7   41    83
# 3            246  ...  0.753   92  320  412  244  52   55   65  128   722
# 4          192.6  ...  0.896   43  219  262  171  58   17   85  120   891
# ..           ...  ...    ...  ...  ...  ...  ...  ..  ...  ...  ...   ...
# 295        174.4  ...  0.767   76  289  365  212  61   29   88  121   874
# 296        242.4  ...  0.606   84  231  315   70  49   61   40  121   390
# 297        232.2  ...  1.000    4    8   12    6   0    2    6   11    27
# 298        180.9  ...  0.802   41  248  289  254  88   28  206  131  1530
# 299        198.6  ...  0.500    0    2    2    2   3    0    2    4     8
#
# [300 rows x 41 columns]

# %% [markdown]
# ### Export as CSV

# %%
merged_data_df.to_csv("Resources/merged_data.csv",index=False)

# %%
wingspan = []
wingspan_convert=[]

wingspan = merged_data_df['WINGSPAN']
# height_wo_shoes = merged_data_df['HEIGHT\xa0W/O\xa0SHOES']
wingspan_list = wingspan.tolist()
for wingspan in wingspan_list:
    wingspan_cleaned = wingspan.strip("'").split("'")
    wingspan_convert.append((int(wingspan_cleaned[0])*12)+(float(wingspan_cleaned[1])))

# %%
merged_data_df['HEIGHT\xa0W/O\xa0SHOES']=wingspan_convert
#merged_data_df
# Out:
#      index               PLAYER    POS BODY FAT % HAND LENGTH (INCHES)  \
# 0        0         Aaron Gordon     PF      5.05%                 8.75
# 1        1        Aaron Holiday     PG      6.40%                 8.75
# 2        2    Admiral Schofield     SF      6.80%                 8.75
# 3        3           Al Horford     PF      9.10%                    -
# 4        4           Alec Burks     SG      5.10%                    9
# ..     ...                  ...    ...        ...                  ...
# 295    300          Will Barton  SG-SF      4.10%                    9
# 296    301  Willie Cauley-Stein      C      6.30%                  9.5
# 297    302         Zach Collins   PF-C      8.90%                 8.75
# 298    303          Zach LaVine     PG      4.70%                 8.25
# 299    304         Zhaire Smith  SF-SG      6.05%                 8.75
#
#     HAND WIDTH (INCHES)  HEIGHT W/O SHOES HEIGHT W/ SHOES STANDING REACH  \
# 0                  10.5             83.75       6' 8.75''         8' 9''
# 1                   8.5             79.50       6' 0.75''         8' 1''
# 2                     9             81.75       6' 5.25''       8' 6.5''
# 3                     -             84.75       6' 9.75''        8' 11''
# 4                  8.25             82.00          6' 6''       8' 7.5''
# ..                  ...               ...             ...            ...
# 295                 9.5             81.75          6' 6''       8' 6.5''
# 296                   9             87.00        7' 0.5''         9' 3''
# 297                9.25             85.00          7' 0''         9' 3''
# 298                8.75             80.25       6' 5.75''         8' 4''
# 299                8.25             81.75          6' 4''         8' 4''
#
#     WEIGHT (LBS)  ...    FT%  ORB  DRB  TRB  AST STL  BLK  TOV   PF   PTS
# 0          220.1  ...  0.675  103  338  441  215  50   36   94  116   833
# 1            187  ...  0.861   21  111  132  193  45   13   75  102   546
# 2          240.6  ...  0.692    6   28   34   14   8    3    7   41    83
# 3            246  ...  0.753   92  320  412  244  52   55   65  128   722
# 4          192.6  ...  0.896   43  219  262  171  58   17   85  120   891
# ..           ...  ...    ...  ...  ...  ...  ...  ..  ...  ...  ...   ...
# 295        174.4  ...  0.767   76  289  365  212  61   29   88  121   874
# 296        242.4  ...  0.606   84  231  315   70  49   61   40  121   390
# 297        232.2  ...  1.000    4    8   12    6   0    2    6   11    27
# 298        180.9  ...  0.802   41  248  289  254  88   28  206  131  1530
# 299        198.6  ...  0.500    0    2    2    2   3    0    2    4     8
#
# [300 rows x 41 columns]
